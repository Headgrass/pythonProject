# %% [markdown]
# АНАЛИЗ списка спасенных людей с затонувшего корабля Titanic

# %%
# Библиотека для работы с табличными данными
import pandas as pd

# %%
ds = pd.read_csv('sample_data/titanic.csv')
ds
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
ds.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %% [markdown]
# В данном случае у нас следующие строки:
#
#
#
# 1.   Survived - Количество выживших
# 2.   Pclass - кто-бы знал
# 3.   Age - Возраст
# 4.   Siblings/Spouses Aboard - Детей/Супругов, оставшихся на борту
# 5.   Parents/Children Aboard - Родителей/детей, оставшихся на борту
# 6.   Fare - Транспортные расходы

# %%
ds[(ds['Age'] < 1) & (ds['Parents/Children Aboard'] > 1)]
# Out:
#      Survived  Pclass                           Name   Sex   Age  \
# 77          1       2   Master. Alden Gates Caldwell  male  0.83
# 303         1       1  Master. Hudson Trevor Allison  male  0.92
#
#      Siblings/Spouses Aboard  Parents/Children Aboard    Fare
# 77                         0                        2   29.00
# 303                        1                        2  151.55

# %% [markdown]
# РЕЗУЛЬТАТ ПОИСКА Из 887 спасенных людей всего детей до 1 года потерявших обоих родителей 2.

# %%
ds[(ds['Age'] > 75)]
# Out:
#      Survived  Pclass                                 Name   Sex   Age  \
# 627         1       1  Mr. Algernon Henry Wilson Barkworth  male  80.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard  Fare
# 627                        0                        0  30.0

# %% [markdown]
# РЕЗУЛЬТАТ ПОИСКА Самому старому спасенному человеку 80 лет

# %%
print(ds['Age'].sum())
# Общий возраст всех спасенных
# Out:
# 26141.17

# %%
print(ds['Age'].mean())
# Средний возраст всех спасенных
# Out:
# 29.471443066516347

# %% [markdown]
# РЕЗУЛЬТАТ ПОИСКА Средний возраст спасенных около 30 лет. Общий вес более 26 т
